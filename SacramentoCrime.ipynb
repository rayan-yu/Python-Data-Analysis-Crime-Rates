# %%
import pandas as pd
import os


CRIME_PATH = os.path.join("datasets", "crime")
def load_crime_data(crime_path=CRIME_PATH):
    csv_path = os.path.join(crime_path, "SacramentocrimeJanuary2006.csv")
    return pd.read_csv(csv_path)

# %%
crime = load_crime_data()
crime.head()
# Out:
#      cdatetime              address  district        beat  grid  \
# 0  1/1/06 0:00   3108 OCCIDENTAL DR         3  3C          1115
# 1  1/1/06 0:00  2082 EXPEDITION WAY         5  5A          1512
# 2  1/1/06 0:00           4 PALEN CT         2  2A           212
# 3  1/1/06 0:00       22 BECKFORD CT         6  6C          1443
# 4  1/1/06 0:00     3421 AUBURN BLVD         2  2A           508
#
#                       crimedescr  ucr_ncic_code   latitude   longitude
# 0  10851(A)VC TAKE VEH W/O OWNER           2404  38.550420 -121.391416
# 1     459 PC  BURGLARY RESIDENCE           2204  38.473501 -121.490186
# 2  10851(A)VC TAKE VEH W/O OWNER           2404  38.657846 -121.462101
# 3   476 PC PASS FICTICIOUS CHECK           2501  38.506774 -121.426951
# 4   459 PC  BURGLARY-UNSPECIFIED           2299  38.637448 -121.384613

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7584 entries, 0 to 7583
# Data columns (total 9 columns):
# cdatetime        7584 non-null object
# address          7584 non-null object
# district         7584 non-null int64
# beat             7584 non-null object
# grid             7584 non-null int64
# crimedescr       7584 non-null object
# ucr_ncic_code    7584 non-null int64
# latitude         7584 non-null float64
# longitude        7584 non-null float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 533.3+ KB

# %%
crime.describe()
# Out:
#           district         grid  ucr_ncic_code     latitude    longitude
# count  7584.000000  7584.000000    7584.000000  7584.000000  7584.000000
# mean      3.574631   916.250791    4275.068829    38.559809  -121.463832
# std       1.642512   407.436310    2171.593193     0.056101     0.034621
# min       1.000000   102.000000     909.000000    38.437999  -121.555832
# 25%       2.000000   567.000000    2309.000000    38.518476  -121.489543
# 50%       3.000000   899.000000    3532.000000    38.559523  -121.465459
# 75%       5.000000  1264.000000    7000.000000    38.610361  -121.435947
# max       6.000000  1661.000000    8102.000000    38.683789  -121.365238

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
crime.hist(bins=50, figsize= (20, 15))
plt.show()

# %%
type1 = pd.DataFrame(crime['crimedescr'])
type1.describe()

type2 = crime['crimedescr']
values = []

for i in range(len(type2)):
    if type2[i] not in values:
        values.append(type2[i])
        
values
# Out:
# ['10851(A)VC TAKE VEH W/O OWNER',
#  '459 PC  BURGLARY RESIDENCE',
#  '476 PC PASS FICTICIOUS CHECK',
#  '459 PC  BURGLARY-UNSPECIFIED',
#  '530.5 PC USE PERSONAL ID INFO',
#  '459 PC  BURGLARY VEHICLE',
#  '484 PC   PETTY THEFT/INSIDE',
#  '459 PC  BURGLARY BUSINESS',
#  '1708 US   THEFT OF MAIL',
#  'ASSAULT WITH WEAPON - I RPT',
#  'SUSP PERS-NO CRIME - I RPT',
#  '484G(B) PC ACCESS CARD FRAUD',
#  '487(A) PC GRAND THEFT',
#  'TELEPEST -I RPT',
#  '487(A) GRAND THEFT-INSIDE',
#  '484J PC PUBLISH CARD INFO',
#  '484 PC PETTY THEFT',
#  'TRAFFIC - I RPT',
#  '594(B)(1)PC  VANDALISM +$400',
#  '484 PC  PETTY THEFT/ OUTSIDE',
#  'HARASSMENT - I RPT',
#  'LOST PROPERTY - I RPT',
#  '484G(A)PC USE FORGED CARD',
#  '503 PC   EMBEZZLEMENT',
#  '653M(A) PC OBSCENE/THREAT CALL',
#  '484 PETTY THEFT/LICENSE PLATE',
#  'FOUND PROPERTY - I RPT',
#  'THREATS - I RPT',
#  '530 PC FALSE PERS. REC PROP',
#  '246 PC SHOOT OCCUP DWELL/VEH',
#  'SHOOT INTO OCCUP DWELL - I RPT',
#  '243(E)1 BATTERY NONCOHAB SPOUS',
#  'MISCELLANEOUS I RPT (ZMISC)',
#  'TOWED/STORED VEH-14602.6',
#  '211 PC ROBBERY- BUSINESS',
#  'CASUALTY REPORT',
#  '23152(A) VC DUI-ALCOHOL/DRUGS',
#  'TRAFFIC-ACCIDENT INJURY',
#  'DUI I RPT',
#  '243(D) PC BATT/CIVILIAN W/INJ',
#  '246.3 PC NEGL DISCH FIREARM',
#  '11351.5 HS POSS SALE RCK COCAI',
#  '211 PC  ROBBERY UNSPECIFIED',
#  '594(B)(2)(A) VANDALISM/ -$400',
#  'TRAFFIC-ACCIDENT-NON INJURY',
#  '475(C) PASS FORGED NOTE',
#  '245(A)(2) AWDW/FIREARM/CIVILIA',
#  '11377(A)HS POSS AMPHETAMINES',
#  '20002(A) HIT/RUN',
#  '5150 WI DANGER SELF/OTHERS',
#  'TOWED/STORED VEHICLE',
#  'IMPOUNDED VEHICLE',
#  'PERSON INFORMATION - I RPT',
#  '653M(B) PC ANNOY/RPT CALL HOME',
#  '484 PETTY THEFT CLOUT UNLOCKED',
#  '10851 VC AUTO THEFT LOCATE',
#  '242 PC  BATTERY CIVILIAN',
#  '506 PC EMBEZZLEMENT/CONTRACTOR',
#  'MISSING PERSON I RPT',
#  'BURGLARY - I RPT',
#  'MISSING PERSON',
#  '11364 HS POSS DRUG PARAPH',
#  '484 PETTY THEFT-SHOPLIFT',
#  'O/S AGENCY -ASSISTANCE- I RPT',
#  '487(D)GRAND THEFT FIREARM/ANIM',
#  '647(A) PC LEWD CONDUCT',
#  'GANG ACTIVITY - I RPT',
#  '422 PC THREAT/INTENT TO TERROR',
#  '20001(A) VC HIT/RUN INJ/DEATH',
#  'NON INJ HR/MAIL OUT REPORT',
#  '197 JUSTIFIABLE HOMI-CIVILIAN',
#  '23153(A) VC DUI CAUSE INJURY',
#  '245(A)(1)AWDW/NO FIREARM/CIVIL',
#  '1551(A) FUGITIVE FROM JUSTICE',
#  '12020(A)(4) PC DIRK/DAGGER',
#  'VANDALISM - I RPT',
#  'ROBBERY - I RPT',
#  'POSS STOLEN VEHICLE- I RPT',
#  '487(A) GRAND THEFT-AUTO PARTS',
#  '484 PC  PETTY THEFT AUTO PART',
#  '529 PC FALSE PERSONATION',
#  '496(A) RECEIVE STOLEN PROPERTY',
#  '11357(B)HS POSS -28.5GR MARIJ',
#  '290(A)(1)(D) FAIL TO REG-5 DAY',
#  '594(B)(1)VANDALISM GRAF +$400',
#  '11350(A)HS POSS CNTRL SUBST',
#  'BATTERY - I RPT',
#  '215(A) PC    CARJACKING',
#  '602(K)TRESPASS:INJURE PROPERTY',
#  '9.04.050 A DRINKING IN PUBLIC',
#  '314.1 PC   INDECENT EXPOSURE',
#  'PETTY THEFT - I RPT',
#  'FAMILY DISTURBANCE - I RPT',
#  '148.9 PC FALSE ID TO OFFICER',
#  'PROTECTIVE CUSTODY-I RPT',
#  'CHILD WELFARE - I RPT',
#  '484 PC-PETTY THEFT-COIN MACHIN',
#  '12420 PC SELL/TRANSP TEAR GAS',
#  '487(A) GRAND THEFT-CLOUT-UNLOC',
#  '187(A)  HOMICIDE',
#  'ACCIDENTAL FIRES/ARSON -I RPT',
#  'BUSINESS PERMITS - I RPT',
#  '9.04.070 URINATE/DEFECATE PUB',
#  'FORGERY-COUNTERFEITING',
#  '290(F)1 W/I 5 DAYS ADD CHANGE',
#  'POSSIBLE MENTAL - I RPT',
#  'NARCOTICS SUSP/EVID/ACT- I RPT',
#  'WARRANT SERVED - I RPT',
#  '3056 PAROLE VIO - I RPT',
#  '10855 VC LSE/RENT NOT RETURNED',
#  'BOMBS/THREATS/EXPLOSIV- I RPT',
#  'JUVENILE PROBLEMS - I RPT',
#  '417(A)1) PC BRANDISH NON-GUN',
#  '211 PC ROBBERY-PURSE SNATCH',
#  '23103(A) RECKLESS ON HIGHWAY',
#  '11352(A)HS SALE/TRANS CNTL SUB',
#  '666 PC PETTY THEFT W/PRI CONV',
#  '3056 PC PAROLE VIOLATION',
#  '602(N)TRESP DRIVE ON PRIVATE P',
#  '240 PC ASSAULT/SIMPLE-CIVILIAN',
#  '2800.2(A) VC EVADING/RECKLESS',
#  '647(F) PC PUB INTOX-DETOX ONLY',
#  '12025(A)2)CNCLD GUN ON PER/FEL',
#  '12022.1 PC COMMIT FEL ON BAIL',
#  'POSSIBLE FINANCIAL CRIME-I RPT',
#  '11532(A)HS LOITER DRG ACTIVITY',
#  '1203.2 PC VIOLATION OF PROBATI',
#  'SAFEKEEPING - I RPT',
#  'MISSING PERSON LOCATE O/S ASSI',
#  '647(B) PC   PROSTITUTION',
#  '647(F) PC DIP - DISORDERLY',
#  '25661 BP FALSE EVIDENCE OF AGE',
#  '166(A)(4) WILFUL DISOBEY CT OR',
#  'FRAUD OR BUNCO - I RPT',
#  '12020(A)1) PROHIBITED FIREARM',
#  '9.40.020(A) JUVENILE CURFEW',
#  '4140 BP  POSS OF HYPO NEEDLE',
#  '11377(A)HS POSS CNTRL SUBST',
#  '273.6(A) PC VIO DV COURT ORDER',
#  '487(A) PC GRAND THEFT-SHOPLIFT',
#  '11550(A)HS UNDER INFL NARCOTIC',
#  '148(A)(1)PC RESIST PEACE OFFCR',
#  'GRAND THEFT - I RPT',
#  '11378 HS POSS/SALE AMPHETAMINE',
#  'SUSPICIOUS VEHICLE - I RPT',
#  '475(A)PC POSS FORGED CHK/NOTE',
#  '11352(B)HS TRANS SUBST TO CNTY',
#  '11359 HS POSS FOR SALE MARIJ',
#  '532 PC FRAUD OBTAIN MONEY ETC',
#  '12500(A) VC UNLIC DRIVER',
#  'RECOVERED PROPERTY - I RPT',
#  '23220 VC DRINKING WHILE DRVING',
#  'PROB VIOLA/FEL-MISD - I RPT',
#  '594(B)(2)(A)VANDALISM GRAF-400',
#  'ABC LICENSE VIO/INFO - I RPT',
#  'HIT AND RUN /SUSPECTS- I RPT',
#  'DAMAGE - I RPT',
#  '211 PC  ROBBERY-BANK',
#  '484E(A)PC THEFT OF CREDIT CARD',
#  '11358 HS CULTIVATE MARIJUANA',
#  '653.22(A) LOITER PROSTITUTION',
#  '14601.1(A) VC LIC SUSP OTHER',
#  '602.1(A)TRES OBST BUSIN OPERAT',
#  'POSSIBLE STOLEN PROPERTY-I RPT',
#  '11360(A)HS SALE/TRANSP MARIJ',
#  '11379(A)HS SALE/TRAN CNTRL SUB',
#  '508 PC   EMBEZZLEMENT/EMPLOYEE',
#  '12021(A)(1)PC FELON POSS FRARM',
#  '148.1(A)PC FALSE REPT OF BOMB',
#  '417(A)2) PC BRANDISH FIREARM',
#  '487(C) PC  GRAND THEFT-PERSON',
#  '290(G)(1) FAIL TO REG SEX OFFE',
#  'TERRORIST THREATS - I RPT',
#  'JUVENILE DISURBANCE - I RPT',
#  '11357(C)HS POSS +28.5GR MARIJ',
#  '243.4(E)(1)TOUCH FOR SEX PLEAS',
#  '247(B) PC SHOOT UNOCC BLDG/VEH',
#  'INTOX REPORT/ADMIN PER - I RPT',
#  'JUVENILE OFFENDER-PROBATION',
#  '451(B) PC ARSON OF INHAB STRUC',
#  '243(C)(1)BATT EMERG PERSON-INJ',
#  'CHILD CUSTODY - I RPT',
#  'FOUND EVIDENCE-NON NARC -I RPT',
#  '212.5(A)ROBBERY-INHAB DWELLING',
#  '22435.2(A) BP POSS SHOP CART',
#  '12303.3 PC DEST DVC INTENT INJ',
#  'NEIGHBORHOOD DISTURBANCE-I RPT',
#  '12403.7(G) PC ILLGL POSS TRGAS',
#  '368(B)(1) CRUELTY/ELDER/ W/INJ',
#  'ELDER ABUSE/PHYS/MENTAL-I RPT',
#  '451(D) PC  ARSON OF PROPERTY',
#  '484 PC   THEFT-LIC PLATE TABS',
#  '290(A)(1)(A) FAIL REG-CHG ADD',
#  '647(I) PEEPING TOM-INHAB DWELL',
#  'FRAUD-SWINDLE',
#  'FILE-UNABLE TO DEFINE - I RPT',
#  '11350(B)HS POSSESS QUAALUDES',
#  '487(D) PC GRAND THEFT AUTO',
#  '12.72.060I ADULT LOITER PLYGRD',
#  '849(B)(1) CERTIFICATE OF RELEA',
#  'CAR CLOUT -  I RPT',
#  '602(L)(1)TRESPASS REFUSE TO LV',
#  '415(1) PC DISTURB PEACE/FIGHT',
#  'HOMICIDE ASSAULT - I RPT',
#  '487(A) GRAND THEFT-COIN MACHIN',
#  '484E(D)PC FRAUD POSS CARD INFO',
#  '12025(A)1)CONCLD GUN VEH/FEL',
#  '4574(A)WEAPON/TEAR GAS IN JAIL',
#  '466 PC   POSS OF BURG TOOLS',
#  '11357(E) MNR POSS MARIJ SCHOOL',
#  'TRESPASS OR PROWLER- I RPT',
#  '664/187(A) ATTEMPTED HOMICIDE',
#  '243.6 BATTERY SCHOOL EMPLOYEE',
#  '415.5(A)(1) PC FIGHT SCHOOL GR',
#  '537(A)(1) DEFRAUD INKEEP/-$400',
#  '278.5(A)DEPRIVE RIGHT OF CUSTO',
#  '11379(A)HS SELL/TRANSP AMPHET',
#  '32 PC ACCESSORY TO A CRIME',
#  '243.2(A)(1) BATT/SCHOOL INJURY',
#  '368(D) THEFT-ELDER >400',
#  'TRAFFIC OFFENSE',
#  '415(3) PC DIST PEACE OFF WORDS',
#  '12031(A)(1)PC LOADED GUN/PUB-M',
#  'LOST PROPERTY-MATRICULA I RPT',
#  '243(B) PC  BATTERY - OFFICER',
#  '1767.3 WI CYA PAROLE HOLD',
#  '417.4 PC BRANDISH IMIT FIREARM',
#  '12025(B)6 UNREG/CONCLED FIREAR',
#  '23222(B)POSSESS MARIJ IN VEH',
#  '23152(B) VC DUI BA .08 OR MORE',
#  '25632 BP CONSM ALC AFT CLOSING',
#  '12303.3 PC FIRE BOMB INT INJ',
#  '470 PC FORGERY',
#  'GRAFFITI PROBLEMS- I RPT',
#  '23550.5 VC 4+DUI IN 10 YEARS',
#  '1705 US DESTRUCT OF MAIL RECEP',
#  '12.52.030 SCC UNLAWFUL CAMPING',
#  '836.6(B) PC ESCAPE FROM ARREST',
#  '4462.5 VC FALSE TAB/AVOID REG',
#  'FALSE PERSONATION - I RPT',
#  'RPT # CANCELLED- I RPT',
#  '10852 VC VEHICLE TAMPERING',
#  '587C PC EVADE PAYMENT RAILFARE',
#  '308(B) PC MINOR POSS TOBACCO',
#  '653K PC POSS/SELL SWITCHBLADE',
#  '241(B) ASSAULT ON POLICE OFFIC',
#  '626.10(A) PC POSS WPN SCHL ZN',
#  'HAZARDOUS SITUATION - I RPT',
#  '485 PC PT OF FOUND PROPERTY',
#  '23110(B) VC THROW AT VEH W/INT',
#  '374.3(A) PC ILLEGAL DUMPING',
#  '11366 HS MAINTN PLACE TO SELL',
#  '594.3(A)VANDAL/PLACE OF WORSHI',
#  'ABANDONED VEHICLE - I RPT',
#  '9.04.050C POSS OPEN CONTAINER',
#  '212.5(B) ROB-VICINITY OF ATM',
#  '5.136.050 NO TAXICAB PERMIT',
#  '368(E) THEFT OF ELDER <$400',
#  '10.48.150 E FALSIFY PKG PERMIT',
#  '12022(A)(1)PC ARMED COMM FEL',
#  '374.4(A) LITTERING',
#  'FRAUDULENT DOCUMENTS- I RPT',
#  '12101(B)1)PC MINOR POSS AMMO',
#  '4463(A)(1) VC ALTER REG',
#  '12025(A)2)CONCL GUN ON PER/MSD',
#  'COLLISION/ACCIDENT BOATS',
#  '243.3 BATT TRANS PERS/PASS/INJ',
#  '11378 HS POSS CNTRL SUB/SALE',
#  'BAIT CAR 10851 VC TAKE VEHICLE',
#  '601(A) WI JUVENILE INCORRIGIBL',
#  'VICE/GAMBLING ACT - I RPT',
#  '13.10.200 SCC DUMP PUB PLACES',
#  '192(C)(2)VEH MAN W/O GROSS NEG',
#  '31 VC FALSE INFO TO OFFICER',
#  '452(D)PC CAUSE FIRE OF PROPERT',
#  '496(A) PC REC STOLEN AUTO PART',
#  '243.4(A) SEXUAL BATTERY',
#  '10853 VC MALIC MISCHIEF TO VEH',
#  '14601(A) VC LIC SUSP NEGLIGENT',
#  '498(B)(5) THEFT OF ELECTRICITY',
#  '12316(B)(1)FELON POSSESS AMMO',
#  '148.4(A)PC TAMPER FIRE PROT EQ',
#  '602.5 PC ENTRY OF PROPERTY',
#  'TRAFFIC ARREST FOR DA-I RPT',
#  '21200.5 VC BICYCLE DUI',
#  '243(C)2 PC BATT/PO WITH INJURY',
#  '9.44.220 SCC ANIMAL AT LARGE',
#  '203 PC    MAYHEM',
#  '11351 HS POSS/SALE OPIATE/NARC',
#  '538D PC IMPERSON PEACE OFFICER',
#  '99170 PUBLIC UTILITIES CODE',
#  '484 PETTY THEFT-PURSE SNATCH',
#  'WANTED SUBJ-O/S WANT/ I RPT',
#  'FORGERY-PASSING COUNTERFEIT',
#  '603  FORCED ENTRY/PROP DAMAGE',
#  '12671 HS SALE/POSS ILLGL FRWRK',
#  '25662(A)BP POSS ALC BY MINOR',
#  '243(B) BATTERY DR/NURSE/EMERG',
#  '245(C) AWDW/NO FIREARM/OFFICER',
#  '11361(B)HS ADLT FURN MNR MARIJ',
#  '32210 EC WILFL DISTURB PUB SCH',
#  '626.2 PC UNAUTH ENTRY CAMPUS',
#  '136.1(C)(1) PC DISSUADE V/W',
#  '368(C) CAUSE PAIN/INJ TO ELDER']

# %%
type1.count()
# Out:
# crimedescr    7584
# dtype: int64

# %%
s = type1['crimedescr'].value_counts()
t = type1['crimedescr'].value_counts().index.tolist()

r = pd.Series(s.head(65))
q = pd.Series(s.head(65))

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()

y_pos = np.arange(len(r))
plt.barh(y_pos, q, align='center', alpha=0.5)
#plt.yticks(y_pos, r)
plt.xlabel('Occurences')
plt.ylabel('Crime by ranking of commonality')
plt.title('Crime Occurences')

plt.show()

# %%
crime.plot(kind="scatter", x="longitude", y="latitude", alpha=0.3)
